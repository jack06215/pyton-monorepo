# %%
import face_recognition
import cv2
import numpy as np

# %%
jack_image = face_recognition.load_image_file("C:\\Users\\jack0\\Pictures\\profile.jpg")
jack_face_encoding = face_recognition.face_encodings(jack_image)[0]

# %%
jack_face_encoding
# Out:
# array([-0.1075516 ,  0.00626676, -0.00447207,  0.00593727, -0.05995138,
#        -0.01713065, -0.05987316, -0.1119662 ,  0.0827739 , -0.10857907,
#         0.27522355, -0.09334712, -0.17964382, -0.10131271, -0.033606  ,
#         0.17366174, -0.21005635, -0.08667233,  0.00627182,  0.01337499,
#         0.09453931, -0.03863864,  0.01742638,  0.0232958 , -0.06841621,
#        -0.30469459, -0.10010734, -0.0990979 ,  0.13144664, -0.09580337,
#        -0.08069859, -0.02305863, -0.19767715, -0.02582907,  0.03393719,
#         0.08427408, -0.03924816, -0.04844755,  0.20513164, -0.00049476,
#        -0.20964889, -0.03158272,  0.03002859,  0.21550322,  0.17111467,
#         0.07694524,  0.00504668, -0.14473   ,  0.12051775, -0.14541918,
#         0.08383193,  0.1125973 ,  0.17249885,  0.05897791, -0.02030194,
#        -0.1410065 ,  0.00299897,  0.1031477 , -0.11480529,  0.05514761,
#         0.09970745, -0.02926262,  0.02510867, -0.03976431,  0.24736491,
# ...
